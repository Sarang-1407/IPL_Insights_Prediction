# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from math import floor
import statsmodels.api as sm
from sklearn.model_selection import train_test_split
from statsmodels.stats.outliers_influence import variance_inflation_factor
from statsmodels.graphics.regressionplots import influence_plot
from sklearn.linear_model import LinearRegression
from sklearn.linear_model import Ridge
from sklearn.linear_model import SGDRegressor
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score
# %matplotlib inline

# matplotlib defaults
plt.style.use("seaborn-whitegrid")
plt.rc("figure", autolayout=True)
plt.rc(
    "axes",
    labelweight="bold",
    labelsize="large",
    titleweight="bold",
    titlesize=14,
    titlepad=10,
)

import warnings
warnings.filterwarnings('ignore')
import os
for dirname, _, filenames in os.walk('/content/IPL IMB381IPL2013.csv'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# <ipython-input-1-146d93b463db>:20: MatplotlibDeprecationWarning: The seaborn styles shipped by Matplotlib are deprecated since 3.6, as they no longer correspond to the styles shipped by seaborn. However, they will remain available as 'seaborn-v0_8-<style>'. Alternatively, directly use the seaborn API instead.
#   plt.style.use("seaborn-whitegrid")

# %%
df = pd.read_csv('/content/IPL IMB381IPL2013.csv', index_col=0)
df.head()
# Out:
#          PLAYER NAME  AGE COUNTRY  TEAM PLAYING ROLE  T-RUNS  T-WKTS  \
# Sl.NO.
# 1        Abdulla, YA    2      SA  KXIP   Allrounder       0       0
# 2       Abdur Razzak    2     BAN   RCB       Bowler     214      18
# 3        Agarkar, AB    2     IND   KKR       Bowler     571      58
# 4          Ashwin, R    1     IND   CSK       Bowler     284      31
# 5       Badrinath, S    2     IND   CSK      Batsman      63       0
#
#         ODI-RUNS-S  ODI-SR-B  ODI-WKTS  ...    SR-B  SIXERS  RUNS-C  WKTS  \
# Sl.NO.                                  ...
# 1                0      0.00         0  ...    0.00       0     307    15
# 2              657     71.41       185  ...    0.00       0      29     0
# 3             1269     80.62       288  ...  121.01       5    1059    29
# 4              241     84.56        51  ...   76.32       0    1125    49
# 5               79     45.93         0  ...  120.71      28       0     0
#
#         AVE-BL   ECON  SR-BL  AUCTION YEAR  BASE PRICE  SOLD PRICE
# Sl.NO.
# 1        20.47   8.90  13.93          2009       50000       50000
# 2         0.00  14.50   0.00          2008       50000       50000
# 3        36.52   8.81  24.90          2008      200000      350000
# 4        22.96   6.23  22.14          2011      100000      850000
# 5         0.00   0.00   0.00          2011      100000      800000
#
# [5 rows x 25 columns]

# %%
print(df.shape)
print(df.info())
# Out:
# (130, 25)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 130 entries, 1 to 130
# Data columns (total 25 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   PLAYER NAME    130 non-null    object
#  1   AGE            130 non-null    int64
#  2   COUNTRY        130 non-null    object
#  3   TEAM           130 non-null    object
#  4   PLAYING ROLE   130 non-null    object
#  5   T-RUNS         130 non-null    int64
#  6   T-WKTS         130 non-null    int64
#  7   ODI-RUNS-S     130 non-null    int64
#  8   ODI-SR-B       130 non-null    float64
#  9   ODI-WKTS       130 non-null    int64
#  10  ODI-SR-BL      130 non-null    float64
#  11  CAPTAINCY EXP  130 non-null    int64
#  12  RUNS-S         130 non-null    int64
#  13  HS             130 non-null    int64
#  14  AVE            130 non-null    float64
#  15  SR-B           130 non-null    float64
#  16  SIXERS         130 non-null    int64
#  17  RUNS-C         130 non-null    int64
#  18  WKTS           130 non-null    int64
#  19  AVE-BL         130 non-null    float64
#  20  ECON           130 non-null    float64
#  21  SR-BL          130 non-null    float64
#  22  AUCTION YEAR   130 non-null    int64
#  23  BASE PRICE     130 non-null    int64
#  24  SOLD PRICE     130 non-null    int64
# dtypes: float64(7), int64(14), object(4)
# memory usage: 26.4+ KB
# None

# %%
print(df.columns)
cat_col = [col for col in df.columns if df[col].dtype == 'object']
num_col = [col for col in df.columns if df[col].dtype in ['float64','int64']]
print(cat_col)
print(num_col)
# Out:
# Index(['PLAYER NAME', 'AGE', 'COUNTRY', 'TEAM', 'PLAYING ROLE', 'T-RUNS',
#        'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL',
#        'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C',
#        'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE',
#        'SOLD PRICE'],
#       dtype='object')
# ['PLAYER NAME', 'COUNTRY', 'TEAM', 'PLAYING ROLE']
# ['AGE', 'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS', 'ODI-SR-BL', 'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS', 'RUNS-C', 'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'AUCTION YEAR', 'BASE PRICE', 'SOLD PRICE']

# %%
df.describe().T.sort_values(by='std', ascending=False)\
.style.background_gradient(cmap='BuPu')
# Out:
# <style type="text/css">
# #T_84816_row0_col0, #T_84816_row1_col0, #T_84816_row2_col0, #T_84816_row2_col3, #T_84816_row2_col4, #T_84816_row2_col5, #T_84816_row3_col0, #T_84816_row3_col3, #T_84816_row3_col4, #T_84816_row3_col5, #T_84816_row4_col0, #T_84816_row4_col1, #T_84816_row4_col2, #T_84816_row4_col3, #T_84816_row4_col4, #T_84816_row4_col5, #T_84816_row4_col6, #T_84816_row4_col7, #T_84816_row5_col0, #T_84816_row5_col1, #T_84816_row5_col2, #T_84816_row5_col3, #T_84816_row5_col4, #T_84816_row5_col5, #T_84816_row5_col6, #T_84816_row5_col7, #T_84816_row6_col0, #T_84816_row6_col1, #T_84816_row6_col2, #T_84816_row6_col3, #T_84816_row6_col4, #T_84816_row6_col5, #T_84816_row6_col6, #T_84816_row6_col7, #T_84816_row7_col0, #T_84816_row7_col1, #T_84816_row7_col2, #T_84816_row7_col3, #T_84816_row7_col4, #T_84816_row7_col5, #T_84816_row7_col6, #T_84816_row7_col7, #T_84816_row8_col0, #T_84816_row8_col1, #T_84816_row8_col2, #T_84816_row8_col3, #T_84816_row8_col4, #T_84816_row8_col5, #T_84816_row8_col6, #T_84816_row8_col7, #T_84816_row9_col0, #T_84816_row9_col1, #T_84816_row9_col2, #T_84816_row9_col3, #T_84816_row9_col4, #T_84816_row9_col5, #T_84816_row9_col6, #T_84816_row9_col7, #T_84816_row10_col0, #T_84816_row10_col1, #T_84816_row10_col2, #T_84816_row10_col3, #T_84816_row10_col4, #T_84816_row10_col5, #T_84816_row10_col6, #T_84816_row10_col7, #T_84816_row11_col0, #T_84816_row11_col1, #T_84816_row11_col2, #T_84816_row11_col3, #T_84816_row11_col4, #T_84816_row11_col5, #T_84816_row11_col6, #T_84816_row11_col7, #T_84816_row12_col0, #T_84816_row12_col1, #T_84816_row12_col2, #T_84816_row12_col3, #T_84816_row12_col4, #T_84816_row12_col5, #T_84816_row12_col6, #T_84816_row12_col7, #T_84816_row13_col0, #T_84816_row13_col1, #T_84816_row13_col2, #T_84816_row13_col3, #T_84816_row13_col4, #T_84816_row13_col5, #T_84816_row13_col6, #T_84816_row13_col7, #T_84816_row14_col0, #T_84816_row14_col1, #T_84816_row14_col2, #T_84816_row14_col3, #T_84816_row14_col4, #T_84816_row14_col5, #T_84816_row14_col6, #T_84816_row14_col7, #T_84816_row15_col0, #T_84816_row15_col1, #T_84816_row15_col2, #T_84816_row15_col3, #T_84816_row15_col4, #T_84816_row15_col5, #T_84816_row15_col6, #T_84816_row15_col7, #T_84816_row16_col0, #T_84816_row16_col1, #T_84816_row16_col2, #T_84816_row16_col3, #T_84816_row16_col4, #T_84816_row16_col5, #T_84816_row16_col6, #T_84816_row16_col7, #T_84816_row17_col0, #T_84816_row17_col1, #T_84816_row17_col2, #T_84816_row17_col3, #T_84816_row17_col4, #T_84816_row17_col5, #T_84816_row17_col6, #T_84816_row17_col7, #T_84816_row18_col0, #T_84816_row18_col1, #T_84816_row18_col2, #T_84816_row18_col6, #T_84816_row18_col7, #T_84816_row19_col0, #T_84816_row19_col1, #T_84816_row19_col2, #T_84816_row19_col3, #T_84816_row19_col4, #T_84816_row19_col5, #T_84816_row19_col6, #T_84816_row19_col7, #T_84816_row20_col0, #T_84816_row20_col1, #T_84816_row20_col2, #T_84816_row20_col3, #T_84816_row20_col4, #T_84816_row20_col5, #T_84816_row20_col6, #T_84816_row20_col7 {
#   background-color: #f7fcfd;
#   color: #000000;
# }
# #T_84816_row0_col1, #T_84816_row0_col2, #T_84816_row0_col3, #T_84816_row0_col4, #T_84816_row0_col5, #T_84816_row0_col6, #T_84816_row0_col7, #T_84816_row1_col3 {
#   background-color: #4d004b;
#   color: #f1f1f1;
# }
# #T_84816_row1_col1 {
#   background-color: #a0bddb;
#   color: #000000;
# }
# #T_84816_row1_col2 {
#   background-color: #9ebcda;
#   color: #000000;
# }
# #T_84816_row1_col4 {
#   background-color: #94a7cf;
#   color: #f1f1f1;
# }
# #T_84816_row1_col5 {
#   background-color: #92a3cd;
#   color: #f1f1f1;
# }
# #T_84816_row1_col6 {
#   background-color: #acc6df;
#   color: #000000;
# }
# #T_84816_row1_col7 {
#   background-color: #88419d;
#   color: #f1f1f1;
# }
# #T_84816_row2_col1, #T_84816_row2_col6, #T_84816_row3_col1, #T_84816_row3_col6, #T_84816_row18_col5 {
#   background-color: #f6fbfd;
#   color: #000000;
# }
# #T_84816_row2_col2, #T_84816_row2_col7, #T_84816_row3_col2, #T_84816_row3_col7, #T_84816_row18_col4 {
#   background-color: #f6fbfc;
#   color: #000000;
# }
# #T_84816_row18_col3 {
#   background-color: #e5eff6;
#   color: #000000;
# }
# </style>
# <table id="T_84816" class="dataframe">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_84816_level0_col0" class="col_heading level0 col0" >count</th>
#       <th id="T_84816_level0_col1" class="col_heading level0 col1" >mean</th>
#       <th id="T_84816_level0_col2" class="col_heading level0 col2" >std</th>
#       <th id="T_84816_level0_col3" class="col_heading level0 col3" >min</th>
#       <th id="T_84816_level0_col4" class="col_heading level0 col4" >25%</th>
#       <th id="T_84816_level0_col5" class="col_heading level0 col5" >50%</th>
#       <th id="T_84816_level0_col6" class="col_heading level0 col6" >75%</th>
#       <th id="T_84816_level0_col7" class="col_heading level0 col7" >max</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_84816_level0_row0" class="row_heading level0 row0" >SOLD PRICE</th>
#       <td id="T_84816_row0_col0" class="data row0 col0" >130.000000</td>
#       <td id="T_84816_row0_col1" class="data row0 col1" >521223.076923</td>
#       <td id="T_84816_row0_col2" class="data row0 col2" >406807.351419</td>
#       <td id="T_84816_row0_col3" class="data row0 col3" >20000.000000</td>
#       <td id="T_84816_row0_col4" class="data row0 col4" >225000.000000</td>
#       <td id="T_84816_row0_col5" class="data row0 col5" >437500.000000</td>
#       <td id="T_84816_row0_col6" class="data row0 col6" >700000.000000</td>
#       <td id="T_84816_row0_col7" class="data row0 col7" >1800000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_84816_level0_row1" class="row_heading level0 row1" >BASE PRICE</th>
#       <td id="T_84816_row1_col0" class="data row1 col0" >130.000000</td>
#       <td id="T_84816_row1_col1" class="data row1 col1" >192230.769231</td>
#       <td id="T_84816_row1_col2" class="data row1 col2" >153097.300897</td>
#       <td id="T_84816_row1_col3" class="data row1 col3" >20000.000000</td>
#       <td id="T_84816_row1_col4" class="data row1 col4" >100000.000000</td>
#       <td id="T_84816_row1_col5" class="data row1 col5" >200000.000000</td>
#       <td id="T_84816_row1_col6" class="data row1 col6" >225000.000000</td>
#       <td id="T_84816_row1_col7" class="data row1 col7" >1350000.000000</td>
#     </tr>
#     <tr>
#       <th id="T_84816_level0_row2" class="row_heading level0 row2" >ODI-RUNS-S</th>
#       <td id="T_84816_row2_col0" class="data row2 col0" >130.000000</td>
#       <td id="T_84816_row2_col1" class="data row2 col1" >2508.738462</td>
#       <td id="T_84816_row2_col2" class="data row2 col2" >3582.205625</td>
#       <td id="T_84816_row2_col3" class="data row2 col3" >0.000000</td>
#       <td id="T_84816_row2_col4" class="data row2 col4" >73.250000</td>
#       <td id="T_84816_row2_col5" class="data row2 col5" >835.000000</td>
#       <td id="T_84816_row2_col6" class="data row2 col6" >3523.500000</td>
#       <td id="T_84816_row2_col7" class="data row2 col7" >18426.000000</td>
#     </tr>
#     <tr>
#       <th id="T_84816_level0_row3" class="row_heading level0 row3" >T-RUNS</th>
#       <td id="T_84816_row3_col0" class="data row3 col0" >130.000000</td>
#       <td id="T_84816_row3_col1" class="data row3 col1" >2166.715385</td>
#       <td id="T_84816_row3_col2" class="data row3 col2" >3305.646757</td>
#       <td id="T_84816_row3_col3" class="data row3 col3" >0.000000</td>
#       <td id="T_84816_row3_col4" class="data row3 col4" >25.500000</td>
#       <td id="T_84816_row3_col5" class="data row3 col5" >542.500000</td>
#       <td id="T_84816_row3_col6" class="data row3 col6" >3002.250000</td>
#       <td id="T_84816_row3_col7" class="data row3 col7" >15470.000000</td>
#     </tr>
#     <tr>
#       <th id="T_84816_level0_row4" class="row_heading level0 row4" >RUNS-S</th>
#       <td id="T_84816_row4_col0" class="data row4 col0" >130.000000</td>
#       <td id="T_84816_row4_col1" class="data row4 col1" >514.246154</td>
#       <td id="T_84816_row4_col2" class="data row4 col2" >615.226335</td>
#       <td id="T_84816_row4_col3" class="data row4 col3" >0.000000</td>
#       <td id="T_84816_row4_col4" class="data row

# %%
for col in cat_col:
    print("total unique values in {} column: ".format(col), df[col].nunique())
for col in num_col:
    print("total unique values in {} column: ".format(col), df[col].nunique())
# Out:
# total unique values in PLAYER NAME column:  130
# total unique values in COUNTRY column:  10
# total unique values in TEAM column:  17
# total unique values in PLAYING ROLE column:  4
# total unique values in AGE column:  3
# total unique values in T-RUNS column:  103
# total unique values in T-WKTS column:  60
# total unique values in ODI-RUNS-S column:  117
# total unique values in ODI-SR-B column:  118
# total unique values in ODI-WKTS column:  74
# total unique values in ODI-SR-BL column:  82
# total unique values in CAPTAINCY EXP column:  2
# total unique values in RUNS-S column:  115
# total unique values in HS column:  73
# total unique values in AVE column:  113
# total unique values in SR-B column:  125
# total unique values in SIXERS column:  48
# total unique values in RUNS-C column:  92
# total unique values in WKTS column:  51
# total unique values in AVE-BL column:  88
# total unique values in ECON column:  83
# total unique values in SR-BL column:  82
# total unique values in AUCTION YEAR column:  4
# total unique values in BASE PRICE column:  17
# total unique values in SOLD PRICE column:  53

# %%
cols = ['COUNTRY','TEAM','PLAYING ROLE']

def cat_plt_func(cols_list):
    for idx, col in enumerate(cols):
        plt.figure(idx, figsize=(10,6))
        sns.countplot(x=col, data=df)
        plt.title("Count of players by {}".format(col))
        plt.ylabel("Number of players by {}".format(col))
        plt.grid()
        plt.show()


cat_plt_func(cols)

# %% [markdown]
# Indian players are sold the most followed by Australians and South Africans
#
# Bolwers are the league's favourite buy
#
# CSK has the maximum number of players followed by RCB and KKR

# %%
plt.figure(figsize=(12,12))
sns.heatmap(data=df[num_col].corr(), annot=True, vmin=-1, vmax=1)
plt.show()

# %% [markdown]
# There's high correlation between 'Run-s', 'HS', 'ave', 'sr-b' and 'sixers'
#
# 'Sixers' and 'Run-s' correlates with sold price
#
# Base price is also in correlation with sold price
#
# 'ODI-SR-B', 'Captaincy Exp' and 'ODI-runs-S' moderatly correlates with sold price

# %%
cols = ['COUNTRY','TEAM','PLAYING ROLE']
for idx, col in enumerate(cols):
    plt.figure(figsize=(8,8))
    sns.boxplot(x=col, y='SOLD PRICE', data=df)
    plt.yticks(list(range(200000,2000000,200000)))
    plt.grid()
    plt.show()

# %% [markdown]
# MI (Mumbai Indians) have paid significantly more compared to their competition.
#
# English Players have gone for a premium price and their range starts at a signficantly higher price. While West Indian players have been a quite cheaper option in the market.
#
# Range of all-rounder's sold price is the highest
#
# Batsmen sold at higher price compared to Wk or bowler

# %%
df['CAPTAINCY EXP'].value_counts()

def cat_func(col):
    plt.figure(figsize=(6,6))
    sns.pointplot(x=col, y='SOLD PRICE', data=df)
    plt.title("Sold price by {}".format(col))
    plt.show()

cat_func('CAPTAINCY EXP')

# %% [markdown]
# players with captaincy exp are sold at high price

# %%
discreat_fea=['AGE','AUCTION YEAR']

for col in discreat_fea:
    cat_func(col)

# %% [markdown]
# Age group depends on sold price while auction year is not must dependent
#
# this shows players are sold on basis on their performance and experience
#
# we will remove auction year from our model

# %%
new_col = [col for col in num_col if df[col].nunique() > 4]
len(new_col)

fig, ax = plt.subplots(6,3, figsize=(12,15))
for idx, col in enumerate(new_col):
    sns.distplot(x=df[col],
                 ax=ax[floor(idx/3),
                       idx%3])
    ax[floor(idx/3), idx%3].grid(visible=True,
                                 color='lightgrey',
                                 linestyle="--" )
    ax[floor(idx/3), idx%3].set_xlabel(col)

plt.suptitle("Distribution of all continuos columns",
             fontsize=15,
             fontweight='bold')
fig.tight_layout()
plt.show()

# %% [markdown]
# Above plots show how continous numerical features are distributed
#
# As we can see base price is approx normally distributed with less dispersion while sold price is widely dispersed, it says how prices are changed from base to sold
#
# Workflow
#
# next steps plot distribution plot of base and sold price with age group and cap exp as hue
#
# plot scatter plot between numerical features and sold price
#
# plot paiplot between most correlated cols
#
# prepare dataframe with avg sold price by player role and age
#
# find ave sold price by cap ex, age and median price by country to add new features
#
# add new feature using ave price by age or cap exp
#
# find premium price by sold-base price and add feature
#
# encode all the cat features to prepare final dataset
#
# drop players name and auction year column
#
# drop multi-correlated cols

# %%
pd.crosstab(index=df['AGE'],
            columns=df['PLAYING ROLE'],
            values=df['SOLD PRICE'],
            aggfunc='count')
# Out:
# PLAYING ROLE  Allrounder  Batsman  Bowler  W. Keeper
# AGE
# 1                    4.0      5.0     7.0        NaN
# 2                   25.0     21.0    29.0       11.0
# 3                    6.0     13.0     8.0        1.0

# %% [markdown]
# we can learn that more number of players are from age group of 2

# %%
x = df[df['CAPTAINCY EXP'] == 0]['SOLD PRICE']

plt.figure(figsize=(12,10))

plt.subplot(2,1,1)
sns.distplot(x=df[df['CAPTAINCY EXP'] == 0]['SOLD PRICE'], label='Without captaincy exp', color='r')
sns.distplot(x=df[df['CAPTAINCY EXP'] == 1]['SOLD PRICE'], label='With captaincy exp', color='g')
plt.xlabel("SOLD PRICE")
plt.xticks(list(range(200000,2000000,200000)),fontsize=13, fontweight='bold')
plt.title("Distribution of sold price by captaincy exp")
plt.legend()

plt.subplot(2,1,2)
sns.distplot(x=df[df['AGE'] == 1]['SOLD PRICE'], label='Age group 1', color='g')
sns.distplot(x=df[df['AGE'] == 2]['SOLD PRICE'], label='Age group 2', color='y')
sns.distplot(x=df[df['AGE'] == 3]['SOLD PRICE'], label='Age group 3', color='r')
plt.xlabel("SOLD PRICE")
plt.xticks(list(range(200000,2000000,200000)),fontsize=13, fontweight='bold')
plt.title("Distribution of sold price by age group")
plt.legend()

plt.suptitle("Distribution of Sold price by Cap exp and Age group", fontsize=18, fontweight='bold')
fig.tight_layout()
plt.show()

# %%
fig, axs = plt.subplots(6,3, figsize=(15,19),constrained_layout=True)
for idx, col in enumerate(new_col):
    axs[floor(idx/3), idx%3].scatter(np.array(df[col]),
                                     np.array(df['SOLD PRICE']),
                                     marker='o')
    axs[floor(idx/3), idx%3].set_xlabel(col)
    axs[floor(idx/3), idx%3].set_ylabel('Sold price')
plt.show()

# %% [markdown]
# Except ECON, SR-BL, AVE-BL, SR-B, ODI-SR-BL all others features are correlating with each other!
#
# We can see RUN-HS, AVE, HS are most correlating with SOLD PRICE

# %%
data = df.loc[:,['RUNS-S','HS','AVE','SIXERS','RUNS-C']]
plt.figure(figsize=(6,6))
sns.pairplot(data,
             height=2,
             kind='scatter')
plt.show()

# %% [markdown]
# All features highly correlate with each other, that is not good for regression model.

# %%
ave_prdf = pd.DataFrame(df.groupby(['AGE','PLAYING ROLE'])['SOLD PRICE'].mean()).reset_index()
print(ave_prdf)
plt.figure(figsize=(8,6))
sns.barplot(x='AGE', y='SOLD PRICE', hue='PLAYING ROLE', data=ave_prdf)
plt.title("Average sold price by age group and playing role")
plt.xticks(fontsize=13, fontweight='bold')
plt.yticks(fontsize=13, fontweight='bold')
plt.legend(title='Playing Role')
plt.show()
# Out:
#     AGE PLAYING ROLE    SOLD PRICE
# 0     1   Allrounder  5.875000e+05
# 1     1      Batsman  1.110000e+06
# 2     1       Bowler  5.177143e+05
# 3     2   Allrounder  4.494000e+05
# 4     2      Batsman  6.547619e+05
# 5     2       Bowler  3.979310e+05
# 6     2    W. Keeper  4.677273e+05
# 7     3   Allrounder  7.666667e+05
# 8     3      Batsman  4.576923e+05
# 9     3       Bowler  4.143750e+05
# 10    3    W. Keeper  7.000000e+05

# %% [markdown]
# We can see how players are sold by age and playing role.
#
# In age group 1, average sold price of batsman in higher same as in ag group 2.
#
# In age group 3, however allrounder are sold at higher price

# %%
av_age = (df.groupby('AGE')['SOLD PRICE'].mean().reset_index()).sort_values(by='SOLD PRICE',
                                                                            ascending=False)
plt.figure(figsize=(8,6))
sns.barplot(x='AGE', y='SOLD PRICE', data=av_age)
plt.title("Average sold price by age group")
plt.xticks(fontsize=13, fontweight='bold')
plt.yticks(fontsize=13, fontweight='bold')
plt.show()
plt.show()

# %% [markdown]
# Average sold price of age group 1 is higher

# %% [markdown]
# ## **Finding the Outliers**

# %%
box = plt.boxplot(df['SOLD PRICE'])
caps = [item.get_ydata()[0] for item in box['caps']]
quantiles =[item.get_ydata()[0] for item in box['whiskers']]
median = [item.get_ydata()[0] for item in box['medians']]
outliers = [item.get_ydata() for item in box['fliers']]


print("Distribution sold price has followong property {}".format(box))
print("--------------------------------------------------------------")
print("--------------------------------------------------------------")
print("Minimum sold price is {} and maximum sold price is {}".format(caps[0],caps[1]))

print('25th quantils is {} and 75th qunatile is {}'.format(quantiles[0],quantiles[1]))

print('Median of the sold price is {}'.format(median[0]))

print("Outliears in sold price are {}".format(outliers))
# Out:
# Distribution sold price has followong property {'whiskers': [<matplotlib.lines.Line2D object at 0x7cebf6dd3910>, <matplotlib.lines.Line2D object at 0x7cebf6dd17b0>], 'caps': [<matplotlib.lines.Line2D object at 0x7cebf6dd3d60>, <matplotlib.lines.Line2D object at 0x7cebf6dd39d0>], 'boxes': [<matplotlib.lines.Line2D object at 0x7cebf6dd1900>], 'medians': [<matplotlib.lines.Line2D object at 0x7cebf6dd2800>], 'fliers': [<matplotlib.lines.Line2D object at 0x7cebf6dd2590>], 'means': []}
# --------------------------------------------------------------
# --------------------------------------------------------------
# Minimum sold price is 20000 and maximum sold price is 1350000
# 25th quantils is 225000.0 and 75th qunatile is 700000.0
# Median of the sold price is 437500.0
# Outliears in sold price are [array([1500000, 1550000, 1800000, 1550000, 1800000, 1800000, 1600000,
#        1800000])]

# %%
df[df['SOLD PRICE'] > 1350000][['PLAYER NAME','AGE','PLAYING ROLE','SOLD PRICE']].sort_values(by='SOLD PRICE',
                                                                                              ascending=False)
# Out:
#           PLAYER NAME  AGE PLAYING ROLE  SOLD PRICE
# Sl.NO.
# 51           Kohli, V    1      Batsman     1800000
# 94          Sehwag, V    2      Batsman     1800000
# 112     Tendulkar, SR    3      Batsman     1800000
# 128      Yuvraj Singh    2      Batsman     1800000
# 114        Tiwary, SS    1      Batsman     1600000
# 24        Flintoff, A    2   Allrounder     1550000
# 84      Pietersen, KP    2      Batsman     1550000
# 16          Dhoni, MS    2    W. Keeper     1500000

# %% [markdown]
# Kohli was sold at highest price being of his age group back in 2013

# %%
lis = [row[0] for row in df[df['SOLD PRICE']> 1350000].itertuples(index=True, name=None)]
print(lis)
# Out:
# [16, 24, 51, 84, 94, 112, 114, 128]

# %% [markdown]
# ## **Feature engineering**

# %%
pre_df = df.copy()
pre_df.drop(['PLAYER NAME','AUCTION YEAR'], inplace=True, axis=1)

pre_df['PREMIUM'] = pre_df['SOLD PRICE'] - pre_df['BASE PRICE']

# %%
cap_df = pre_df.groupby('CAPTAINCY EXP')['SOLD PRICE'].mean().reset_index()

combined_df = pd.merge(pre_df, cap_df, how='left', on='CAPTAINCY EXP')
combined_df.rename(columns={'SOLD PRICE_x':'SOLD PRICE',
                    'SOLD PRICE_y':'AVE PRICE BY CAP'}, inplace=True)

coun_sp = pre_df.groupby('COUNTRY')['SOLD PRICE'].median().reset_index()
final_df = pd.merge(combined_df, coun_sp, how='left', on='COUNTRY')
final_df.rename(columns={'SOLD PRICE_x':'SOLD PRICE',
                    'SOLD PRICE_y':'AVE PRICE BY COUNTRY'}, inplace=True)


encoded_df = pd.get_dummies(final_df,
                            columns=['COUNTRY', 'TEAM', 'PLAYING ROLE'],
                            drop_first=True)


lis = [row[0] for row in df[df['SOLD PRICE']> 1350000].itertuples(index=True, name=None)]
after_df = encoded_df.drop(lis, axis=0)

print("Final columns for model training: \n", encoded_df.columns)
print("---------------------------------------------------------")
print("---------------------------------------------------------")
print("Shape of the final dataset: ", encoded_df.shape)
print("---------------------------------------------------------")
print("---------------------------------------------------------")
print("Data types of columns:\n", encoded_df.dtypes)
print("---------------------------------------------------------")
print("---------------------------------------------------------")
print("Shape of after_df: ", after_df.shape)
# Out:
# Final columns for model training:
#  Index(['AGE', 'T-RUNS', 'T-WKTS', 'ODI-RUNS-S', 'ODI-SR-B', 'ODI-WKTS',
#        'ODI-SR-BL', 'CAPTAINCY EXP', 'RUNS-S', 'HS', 'AVE', 'SR-B', 'SIXERS',
#        'RUNS-C', 'WKTS', 'AVE-BL', 'ECON', 'SR-BL', 'BASE PRICE', 'SOLD PRICE',
#        'PREMIUM', 'AVE PRICE BY CAP', 'AVE PRICE BY COUNTRY', 'COUNTRY_BAN',
#        'COUNTRY_ENG', 'COUNTRY_IND', 'COUNTRY_NZ', 'COUNTRY_PAK', 'COUNTRY_SA',
#        'COUNTRY_SL', 'COUNTRY_WI', 'COUNTRY_ZIM', 'TEAM_CSK+', 'TEAM_DC',
#        'TEAM_DC+', 'TEAM_DD', 'TEAM_DD+', 'TEAM_KKR', 'TEAM_KKR+', 'TEAM_KXI+',
#        'TEAM_KXIP', 'TEAM_KXIP+', 'TEAM_MI', 'TEAM_MI+', 'TEAM_RCB',
#        'TEAM_RCB+', 'TEAM_RR', 'TEAM_RR+', 'PLAYING ROLE_Batsman',
#        'PLAYING ROLE_Bowler', 'PLAYING ROLE_W. Keeper'],
#       dtype='object')
# ---------------------------------------------------------
# ---------------------------------------------------------
# Shape of the final dataset:  (130, 51)
# ---------------------------------------------------------
# ---------------------------------------------------------
# Data types of columns:
#  AGE                         int64
# T-RUNS                      int64
# T-WKTS                      int64
# ODI-RUNS-S                  int64
# ODI-SR-B                  float64
# ODI-WKTS                    int64
# ODI-SR-BL                 float64
# CAPTAINCY EXP               int64
# RUNS-S                      int64
# HS                          int64
# AVE                       float64
# SR-B                      float64
# SIXERS                      int64
# RUNS-C                      int64
# WKTS                        int64
# AVE-BL                    float64
# ECON                      float64
# SR-BL                     float64
# BASE PRICE                  int64
# SOLD PRICE                  int64
# PREMIUM                     int64
# AVE PRICE BY CAP          float64
# AVE PRICE BY COUNTRY      float64
# COUNTRY_BAN                 uint8
# COUNTRY_ENG                 uint8
# COUNTRY_IND                 uint8
# COUNTRY_NZ                  uint8
# COUNTRY_PAK                 uint8
# COUNTRY_SA                  uint8
# COUNTRY_SL                  uint8
# COUNTRY_WI                  uint8
# COUNTRY_ZIM                 uint8
# TEAM_CSK+                   uint8
# TEAM_DC                     uint8
# TEAM_DC+                    uint8
# TEAM_DD                     uint8
# TEAM_DD+                    uint8
# TEAM_KKR                    uint8
# TEAM_KKR+                   uint8
# TEAM_KXI+                   uint8
# TEAM_KXIP                   uint8
# TEAM_KXIP+                  uint8
# TEAM_MI                     uint8
# TEAM_MI+                    uint8
# TEAM_RCB                    uint8
# TEAM_RCB+                   uint8
# TEAM_RR                     uint8
# TEAM_RR+                    uint8
# PLAYING ROLE_Batsman        uint8
# PLAYING ROLE_Bowler         uint8
# PLAYING ROLE_W. Keeper      uint8
# dtype: object
# ---------------------------------------------------------
# ---------------------------------------------------------
# Shape of after_df:  (122, 51)

# %% [markdown]
# ## **Model Building and Training**

# %%
train_test_df = after_df.copy()

X = sm.add_constant(train_test_df.drop('SOLD PRICE', axis=1))
y = train_test_df['SOLD PRICE']

X.shape, y.shape


train_X, val_X, train_y, val_y  = train_test_split(X, y,
                                                   train_size=0.8,
                                                   test_size=0.2,
                                                   random_state=42)

# %%
sm_model = sm.OLS(train_y,train_X).fit()
sm_model.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                           Results: Ordinary least squares
# ====================================================================================
# Model:                     OLS                   Adj. R-squared:          1.000
# Dependent Variable:        SOLD PRICE            AIC:                     -3753.3329
# Date:                      2023-10-02 15:35      BIC:                     -3627.1721
# No. Observations:          97                    Log-Likelihood:          1925.7
# Df Model:                  48                    F-statistic:             4.989e+29
# Df Residuals:              48                    Prob (F-statistic):      0.00
# R-squared:                 1.000                 Scale:                   6.7550e-19
# ------------------------------------------------------------------------------------
#                         Coef.  Std.Err.           t           P>|t|   [0.025  0.975]
# ------------------------------------------------------------------------------------
# const                   0.0000   0.0000                1.8647 0.0683 -0.0000  0.0000
# AGE                    -0.0000   0.0000               -1.3620 0.1796 -0.0000  0.0000
# T-RUNS                 -0.0000   0.0000               -1.4427 0.1556 -0.0000  0.0000
# T-WKTS                  0.0000   0.0000                0.2987 0.7665 -0.0000  0.0000
# ODI-RUNS-S              0.0000   0.0000                1.1811 0.2434 -0.0000  0.0000
# ODI-SR-B               -0.0000   0.0000               -0.4703 0.6403 -0.0000  0.0000
# ODI-WKTS                0.0000   0.0000                0.4870 0.6285 -0.0000  0.0000
# ODI-SR-BL               0.0000   0.0000                0.0727 0.9424 -0.0000  0.0000
# CAPTAINCY EXP          -0.0000   0.0000               -1.7362 0.0889 -0.0000  0.0000
# RUNS-S                 -0.0000   0.0000               -0.1469 0.8838 -0.0000  0.0000
# HS                      0.0000   0.0000                0.0434 0.9656 -0.0000  0.0000
# AVE                    -0.0000   0.0000               -0.4636 0.6450 -0.0000  0.0000
# SR-B                   -0.0000   0.0000               -0.5183 0.6066 -0.0000  0.0000
# SIXERS                 -0.0000   0.0000               -0.3211 0.7495 -0.0000  0.0000
# RUNS-C                 -0.0000   0.0000               -1.4163 0.1632 -0.0000  0.0000
# WKTS                    0.0000   0.0000                1.1374 0.2610 -0.0000  0.0000
# AVE-BL                  0.0000   0.0000                2.1849 0.0338  0.0000  0.0000
# ECON                   -0.0000   0.0000               -0.0035 0.9972 -0.0000  0.0000
# SR-BL                  -0.0000   0.0000               -2.1246 0.0388 -0.0000 -0.0000
# BASE PRICE              1.0000   0.0000  536685147855127.5625 0.0000  1.0000  1.0000
# PREMIUM                 1.0000   0.0000 2415873853827304.5000 0.0000  1.0000  1.0000
# AVE PRICE BY CAP        0.0000   0.0000                1.0871 0.2824 -0.0000  0.0000
# AVE PRICE BY COUNTRY   -0.0000   0.0000               -0.5567 0.5803 -0.0000  0.0000
# COUNTRY_BAN            -0.0000   0.0000               -0.4741 0.6376 -0.0000  0.0000
# COUNTRY_ENG            -0.0000   0.0000               -0.7649 0.4481 -0.0000  0.0000
# COUNTRY_IND            -0.0000   0.0000               -0.4010 0.6902 -0.0000  0.0000
# COUNTRY_NZ              0.0000   0.0000                0.2894 0.7736 -0.0000  0.0000
# COUNTRY_PAK            -0.0000   0.0000               -0.6355 0.5281 -0.0000  0.0000
# COUNTRY_SA              0.0000   0.0000                0.1700 0.8657 -0.0000  0.0000
# COUNTRY_SL              0.0000   0.0000                0.1568 0.8761 -0.0000  0.0000
# COUNTRY_WI             -0.0000   0.0000               -0.5486 0.5858 -0.0000  0.0000
# COUNTRY_ZIM             0.0000   0.0000                0.2091 0.8353 -0.0000  0.0000
# TEAM_CSK+              -0.0000   0.0000               -0.0369 0.9707 -0.0000  0.0000
# TEAM_DC                -0.0000   0.0000               -0.4130 0.6814 -0.0000  0.0000
# TEAM_DC+                0.0000   0.0000                0.4686 0.6415 -0.0000  0.0000
# TEAM_DD                -0.0000   0.0000               -0.0750 0.9405 -0.0000  0.0000
# TEAM_DD+                0.0000   0.0000                0.0605 0.9520 -0.0000  0.0000
# TEAM_KKR               -0.0000   0.0000               -0.7797 0.4394 -0.0000  0.0000
# TEAM_KKR+               0.0000   0.0000                0.5228 0.6035 -0.0000  0.0000
# TEAM_KXI+              -0.0000   0.0000               -0.3070 0.7601 -0.0000  0.0000
# TEAM_KXIP              -0.0000   0.0000               -0.1884 0.8514 -0.0000  0.0000
# TEAM_KXIP+             -0.0000   0.0000               -0.1438 0.8863 -0.0000  0.0000
# TEAM_MI                -0.0000   0.0000               -0.1779 0.8595 -0.0000  0.0000
# TEAM_MI+                0.0000   0.0000                0.1986 0.8434 -0.0000  0.0000
# TEAM_RCB               -0.0000   0.0000               -0.0150 0.9881 -0.0000  0.0000
# TEAM_RCB+               0.0000   0.0000                0.3027 0.7634 -0.0000  0.0000
# TEAM_RR                -0.0000   0.0000               -0.6251 0.5349 -0.0000  0.0000
# TEAM_RR+                0.0000   0.0000                0.2300 0.8190 -0.0000  0.0000
# PLAYING ROLE_Batsman    0.0000   0.0000                0.4621 0.6461 -0.0000  0.0000
# PLAYING ROLE_Bowler    -0.0000   0.0000               -0.3334 0.7403 -0.0000  0.0000
# PLAYING ROLE_W. Keeper  0.0000   0.0000                0.0446 0.9646 -0.0000  0.0000
# ------------------------------------------------------------------------------------
# Omnibus:                0.037           Durbin-Watson:             2.023
# Prob(Omnibus):          0.982           Jarque-Bera (JB):          0.131
# Skew:                   -0.044          Prob(JB):                  0.937
# Kurtosis:               2.843           Condition No.:             16111950983495882
# ====================================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly
# specified.
# [2] The smallest eigenvalue is 2.54e-19. This might indicate that
# there are strong multicollinearity problems or that the design                matrix
# is singular.
# """

# %% [markdown]
# Model is over-fitted to the dataset, there is lot of noise in data and we need to remove multi-colinear columns as well as value that are not statistically significant

# %% [markdown]
# We need to check variation inflation factor of all the features and remove all the columsn which will have collinearity

# %%
def get_vif(X):
    #X_matrix = X.as_matrix()
    vif = [variance_inflation_factor(X, i) for i in range(X.shape[1])]
    vif_factors = pd.DataFrame({'COLUMN':X.columns,
                                 'VIF': vif})
    return vif_factors

vif_factors = get_vif(X)
vif_factors.head(10)
# Out:
#           COLUMN        VIF
# 0          const   0.000000
# 1            AGE   2.412930
# 2         T-RUNS  10.923642
# 3         T-WKTS   8.318430
# 4     ODI-RUNS-S  12.618828
# 5       ODI-SR-B   1.880863
# 6       ODI-WKTS  11.433963
# 7      ODI-SR-BL   2.039362
# 8  CAPTAINCY EXP        inf
# 9         RUNS-S  13.207284

# %% [markdown]
# If VIF is more than 4 then, it is not good and those features are affecting model performance by inflating variance in regression coefficiants

# %%
vif_greater_than_4 = vif_factors[vif_factors.VIF > 4][['COLUMN','VIF']]
vif_greater_than_4[:10]
# Out:
#            COLUMN        VIF
# 2          T-RUNS  10.923642
# 3          T-WKTS   8.318430
# 4      ODI-RUNS-S  12.618828
# 6        ODI-WKTS  11.433963
# 8   CAPTAINCY EXP        inf
# 9          RUNS-S  13.207284
# 10             HS  11.138260
# 11            AVE  12.153290
# 13         SIXERS   8.043308
# 14         RUNS-C  29.755100

# %% [markdown]
# Above columns are having VIF more than 4 we need to check multi collinearity from our previous heatmap and pariplot observations
#
# we will remove columms serial no. 2,4,6,8,9,11,13,14,16,19,22,23,24,25,26,27,29,30,31,48

# %%
columns_keep = ['T-WKTS','HS','WKTS','SR-BL','AVE PRICE BY CAP']

vif_greater_less_4 = list(vif_factors[vif_factors.VIF < 4]['COLUMN'])

#new columns to keep

new_lis = columns_keep + vif_greater_less_4
X_new = X[new_lis]

get_vif(X_new)[:10]
# Out:
#              COLUMN        VIF
# 0            T-WKTS   1.778871
# 1                HS   3.065363
# 2              WKTS   2.085018
# 3             SR-BL   3.119854
# 4  AVE PRICE BY CAP   1.960487
# 5             const  80.201282
# 6               AGE   1.641878
# 7          ODI-SR-B   1.603011
# 8         ODI-SR-BL   1.794891
# 9              SR-B   1.879593

# %%
X_train = train_X[new_lis]

sm_model2 = sm.OLS(train_y, X_train).fit()
sm_model2.summary2()
# Out:
# <class 'statsmodels.iolib.summary2.Summary'>
# """
#                             Results: Ordinary least squares
# =======================================================================================
# Model:                      OLS                    Adj. R-squared:           0.845
# Dependent Variable:         SOLD PRICE             AIC:                      2626.7042
# Date:                       2023-10-02 15:35       BIC:                      2706.5202
# No. Observations:           97                     Log-Likelihood:           -1282.4
# Df Model:                   30                     F-statistic:              18.41
# Df Residuals:               66                     Prob (F-statistic):       6.36e-22
# R-squared:                  0.893                  Scale:                    2.6158e+10
# ---------------------------------------------------------------------------------------
#                           Coef.       Std.Err.     t    P>|t|     [0.025       0.975]
# ---------------------------------------------------------------------------------------
# T-WKTS                     240.2722    187.8605  1.2790 0.2054    -134.8035    615.3478
# HS                         337.7315    787.2649  0.4290 0.6693   -1234.0935   1909.5565
# WKTS                      -149.9109   1117.5763 -0.1341 0.8937   -2381.2240   2081.4022
# SR-BL                      983.1346   1891.9654  0.5196 0.6051   -2794.2962   4760.5654
# AVE PRICE BY CAP             0.4747      0.1899  2.4994 0.0149       0.0955      0.8539
# const                  -135270.5382 168087.8531 -0.8048 0.4238 -470868.7649 200327.6885
# AGE                      34136.7208  39321.9766  0.8681 0.3885  -44372.1386 112645.5801
# ODI-SR-B                   371.0501    845.7380  0.4387 0.6623   -1317.5204   2059.6206
# ODI-SR-BL                   86.1725    792.5428  0.1087 0.9137   -1496.1901   1668.5352
# SR-B                      -112.8751    719.1595 -0.1570 0.8758   -1548.7233   1322.9731
# ECON                      -797.3292   5077.5843 -0.1570 0.8757  -10935.0534   9340.3950
# PREMIUM                      1.0549      0.0623 16.9215 0.0000       0.9304      1.1793
# COUNTRY_SA              -79038.8987  59154.2824 -1.3361 0.1861 -197144.2342  39066.4368
# TEAM_CSK+               -66970.5205  99465.6887 -0.6733 0.5031 -265560.1754 131619.1345
# TEAM_DC                 -78176.0203  88668.4243 -0.8817 0.3812 -255208.2413  98856.2007
# TEAM_DC+                -65700.3678  78101.1031 -0.8412 0.4033 -221634.2513  90233.5156
# TEAM_DD                  -2817.0213 100669.0695 -0.0280 0.9778 -203809.3035 198175.2608
# TEAM_DD+                -73511.5556  88361.8381 -0.8319 0.4084 -249931.6574 102908.5463
# TEAM_KKR                -44396.7075  91518.2692 -0.4851 0.6292 -227118.8274 138325.4123
# TEAM_KKR+               -94968.0128  78384.8869 -1.2116 0.2300 -251468.4890  61532.4633
# TEAM_KXI+                -7476.1221 179596.1248 -0.0416 0.9669 -366051.3545 351099.1103
# TEAM_KXIP               -12089.9523 120504.0722 -0.1003 0.9204 -252684.0951 228504.1904
# TEAM_KXIP+              -52273.3740  87359.5718 -0.5984 0.5516 -226692.3866 122145.6386
# TEAM_MI                 -93056.9764  95185.1854 -0.9776 0.3318 -283100.3307  96986.3780
# TEAM_MI+               -119389.9828 140683.8222 -0.8486 0.3991 -400274.2965 161494.3310
# TEAM_RCB               -172527.3593  84495.2575 -2.0419 0.0452 -341227.5839  -3827.1347
# TEAM_RCB+                43065.5905  74110.4635  0.5811 0.5632 -104900.7240 191031.9050
# TEAM_RR                 -59475.8065 108068.9339 -0.5504 0.5839 -275242.3946 156290.7816
# TEAM_RR+                -81968.7103  91344.9749 -0.8974 0.3728 -264344.8369 100407.4164
# PLAYING ROLE_Bowler       4964.7157  61998.6486  0.0801 0.9364 -118819.5802 128749.0116
# PLAYING ROLE_W. Keeper  -19479.7699  72087.7641 -0.2702 0.7878 -163407.6347 124448.0950
# ---------------------------------------------------------------------------------------
# Omnibus:                     122.027             Durbin-Watson:                2.047
# Prob(Omnibus):               0.000               Jarque-Bera (JB):             3168.743
# Skew:                        4.153               Prob(JB):                     0.000
# Kurtosis:                    29.740              Condition No.:                9666126
# =======================================================================================
# Notes:
# [1] Standard Errors assume that the covariance matrix of the errors is correctly
# specified.
# [2] The condition number is large, 9.67e+06. This might indicate                that
# there are strong multicollinearity or other numerical                problems.
# """

# %% [markdown]
# > R2 is significant up to 86% than previous model

# %%
pred_y = sm_model2.predict(val_X[new_lis])

# scoring
def scorer(pred, val):
    RMSE = np.sqrt(mean_squared_error(pred_y,val_y))
    R2 = r2_score(pred_y,val_y)
    return RMSE, R2


print("RMSE and R2 are as follow: ", scorer(pred_y,val_y))
# Out:
# RMSE and R2 are as follow:  (87902.76366835456, 0.9637118332369121)

# %%
def pp_plot(model, title):
    plt.figure(figsize=(8,6))
    probplot = sm.ProbPlot(model.resid)
    probplot.ppplot(line='45')
    plt.title(title)
    plt.show()
pp_plot(sm_model2, 'P-P Plot')

# %%
def get_std_values(val):
    std_val = (val - val.mean())/val.std()
    return std_val

# Residule plot
def residual_plot(fitted, residual, title):
    plt.figure(figsize=(8,6))
    plt.scatter(get_std_values(fitted),
                get_std_values(residual))
    plt.title(title, fontsize=15)
    plt.xlabel("Standardized Fitted values of best-fit line")
    plt.ylabel("Standardized Residula of observations")
    plt.show()

residual_plot(sm_model2.fittedvalues, sm_model2.resid, 'Residual plot')

# %% [markdown]
# As per the residulas plot there are couple of outliers that are affecting the model.

# %%
fig, ax = plt.subplots(figsize=(8,6))
influence_plot(sm_model2, ax=ax)
plt.title('Leverage value vs Residuals')
plt.show()

# %% [markdown]
# index number 55 has higher leverage on residuals compared to others

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.linear_model import LinearRegression

X_trn = train_X[new_lis].drop('const', axis=1)
X_tst = val_X[new_lis].drop('const', axis=1)
train_y, val_y

def model_function(mod,**kwargs):
    model = mod(**kwargs)
    model.fit(X_trn,train_y)
    pre_y = model.predict(X_tst)
    RMSE = round(np.sqrt(mean_squared_error(pre_y,val_y)), 3)
    R2 = round(r2_score(pre_y,val_y)*100, 3)
    return RMSE, R2

print("RMSE and R2 of Linear regression model are: ",
      model_function(LinearRegression))
# Out:
# RMSE and R2 of Linear regression model are:  (87902.764, 96.371)

# %%
print("RMSE and R2 of Ridge regression model are: ", model_function(Ridge, alpha=0.15))
# Out:
# RMSE and R2 of Ridge regression model are:  (84222.506, 96.655)

# %%
print("RMSE and R2 of SGD regression model are: ", model_function(SGDRegressor, early_stopping=True))
# Out:
# RMSE and R2 of SGD regression model are:  (9.145043112886984e+20, -689.582)

# %%
print("RMSE and R2 of Decision tree regression model are: ",
      model_function(DecisionTreeRegressor, max_features='auto', random_state=0))
# Out:
# RMSE and R2 of Decision tree regression model are:  (397666.493, 37.026)

# %%
print("RMSE and R2 of Random Forest regression model are: ",
      model_function(RandomForestRegressor, n_estimators=210, random_state=0))
# Out:
# RMSE and R2 of Random Forest regression model are:  (127589.38, 91.522)

# %% [markdown]
# Best performer is RIDGE Regresison model with accuracy of 96.65%

# %% [markdown]
# ### **Prediction Models on VIRAT KOHLI**

# %%
new_player_data = pd.DataFrame({
    'AGE': [1],
    'RUNS-S' : [1639],
    'HS': [73],
    'AVE': [28.86],
    'SIXERS': [49],
    'SR-B' : [119.29],
    'CAPTAINCY EXP' : [1],
    'ODI-RUNS-S' : [3590],
    'BASE PRICE' : [150000],

})

selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']

model = LinearRegression()
model.fit(X, y)

predicted_price = model.predict(new_player_data[selected_features])

print(f'Predicted Sold Price: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price: 1008542.52

# %%
selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']


ridge_model = Ridge(alpha=0.15)

ridge_model.fit(X, y)

new_player_data = pd.DataFrame({
    'AGE': [1],
    'HS': [73],
    'AVE': [28.86],
    'SIXERS': [49],
    'RUNS-S': [1639],
    'SR-B': [119.29],
    'CAPTAINCY EXP': [1],
    'ODI-RUNS-S': [3590],
    'BASE PRICE': [150000]
})

predicted_price = ridge_model.predict(new_player_data)

print(f'Predicted Sold Price for New Player: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price for New Player: 1007628.89

# %%
selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']


decision_tree_model = DecisionTreeRegressor(max_features='auto', random_state=0)

decision_tree_model.fit(X, y)

new_player_data = pd.DataFrame({
    'AGE': [1],
    'HS': [73],
    'AVE': [30],
    'SIXERS': [49],
    'RUNS-S': [1639],
    'SR-B': [119.29],
    'CAPTAINCY EXP': [1],
    'ODI-RUNS-S': [3590],
    'BASE PRICE': [150000]
})

predicted_price = decision_tree_model.predict(new_player_data)

print(f'Predicted Sold Price for New Player: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price for New Player: 1800000.00

# %%
selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']

random_forest_model = RandomForestRegressor(n_estimators=210, random_state=0)

random_forest_model.fit(X, y)

new_player_data = pd.DataFrame({
    'AGE': [1],
    'HS': [73],
    'AVE': [28.86],
    'SIXERS': [49],
    'RUNS-S': [1639],
    'SR-B': [119.29],
    'CAPTAINCY EXP': [1],
    'ODI-RUNS-S': [3590],
    'BASE PRICE': [150000]
})

predicted_price = random_forest_model.predict(new_player_data)

print(f'Predicted Sold Price for New Player: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price for New Player: 1354261.90

# %% [markdown]
# ### **Prediction Models on Suresh Raina**

# %%
new_player_data = pd.DataFrame({
    'AGE': [1],
    'HS': [98],
    'AVE': [33.64],
    'SIXERS': [97],
    'RUNS-S': [2254],
    'SR-B': [139.39],
    'CAPTAINCY EXP': [0],
    'ODI-RUNS-S': [3525],
    'BASE PRICE': [125000]
})

selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']

model = LinearRegression()
model.fit(X, y)

predicted_price = model.predict(new_player_data[selected_features])

print(f'Predicted Sold Price: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price: 1176856.27

# %%
selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']


ridge_model = Ridge(alpha=0.15)

ridge_model.fit(X, y)

new_player_data = pd.DataFrame({
    'AGE': [1],
    'HS': [98],
    'AVE': [33.64],
    'SIXERS': [97],
    'RUNS-S': [2254],
    'SR-B': [139.39],
    'CAPTAINCY EXP': [0],
    'ODI-RUNS-S': [3525],
    'BASE PRICE': [125000]
})

predicted_price = ridge_model.predict(new_player_data)

print(f'Predicted Sold Price for New Player: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price for New Player: 1176647.69

# %%
selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']


decision_tree_model = DecisionTreeRegressor(max_features='auto', random_state=0)

decision_tree_model.fit(X, y)

new_player_data = pd.DataFrame({
    'AGE': [1],
    'HS': [98],
    'AVE': [33.64],
    'SIXERS': [97],
    'RUNS-S': [2254],
    'SR-B': [139.39],
    'CAPTAINCY EXP': [0],
    'ODI-RUNS-S': [3525],
    'BASE PRICE': [125000]
})

predicted_price = decision_tree_model.predict(new_player_data)

print(f'Predicted Sold Price for New Player: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price for New Player: 650000.00

# %%
selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']

random_forest_model = RandomForestRegressor(n_estimators=210, random_state=0)

random_forest_model.fit(X, y)

new_player_data = pd.DataFrame({
    'AGE': [1],
    'HS': [98],
    'AVE': [33.64],
    'SIXERS': [97],
    'RUNS-S': [2254],
    'SR-B': [139.39],
    'CAPTAINCY EXP': [0],
    'ODI-RUNS-S': [3525],
    'BASE PRICE': [125000]
})

predicted_price = random_forest_model.predict(new_player_data)

print(f'Predicted Sold Price for New Player: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price for New Player: 744380.95

# %% [markdown]
# ### **Prediction Models on Mike Hussey**

# %%
new_player_data = pd.DataFrame({
    'AGE': [3],
    'HS': [116],
    'AVE': [39.92],
    'SIXERS': [25],
    'RUNS-S': [958],
    'SR-B': [120.65],
    'CAPTAINCY EXP': [1],
    'ODI-RUNS-S': [5262],
    'BASE PRICE': [250000]
})

selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']

model = LinearRegression()
model.fit(X, y)

predicted_price = model.predict(new_player_data[selected_features])

print(f'Predicted Sold Price: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price: 417590.92

# %%
selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']


ridge_model = Ridge(alpha=0.15)

ridge_model.fit(X, y)

new_player_data = pd.DataFrame({
    'AGE': [3],
    'HS': [116],
    'AVE': [39.92],
    'SIXERS': [25],
    'RUNS-S': [958],
    'SR-B': [120.65],
    'CAPTAINCY EXP': [1],
    'ODI-RUNS-S': [5262],
    'BASE PRICE': [250000]
})

predicted_price = ridge_model.predict(new_player_data)

print(f'Predicted Sold Price for New Player: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price for New Player: 417807.77

# %%
selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']


decision_tree_model = DecisionTreeRegressor(max_features='auto', random_state=0)

decision_tree_model.fit(X, y)

new_player_data = pd.DataFrame({
    'AGE': [3],
    'HS': [116],
    'AVE': [39.92],
    'SIXERS': [25],
    'RUNS-S': [958],
    'SR-B': [120.65],
    'CAPTAINCY EXP': [1],
    'ODI-RUNS-S': [5262],
    'BASE PRICE': [250000]
})

predicted_price = decision_tree_model.predict(new_player_data)

print(f'Predicted Sold Price for New Player: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price for New Player: 250000.00

# %%
selected_features = ['AGE', 'HS', 'AVE', 'SIXERS', 'RUNS-S', 'SR-B', 'CAPTAINCY EXP', 'ODI-RUNS-S', 'BASE PRICE']
X = df[selected_features]
y = df['SOLD PRICE']

random_forest_model = RandomForestRegressor(n_estimators=210, random_state=0)

random_forest_model.fit(X, y)

new_player_data = pd.DataFrame({
    'AGE': [3],
    'HS': [116],
    'AVE': [39.92],
    'SIXERS': [25],
    'RUNS-S': [958],
    'SR-B': [120.65],
    'CAPTAINCY EXP': [1],
    'ODI-RUNS-S': [5262],
    'BASE PRICE': [250000]
})

predicted_price = random_forest_model.predict(new_player_data)

print(f'Predicted Sold Price for New Player: {predicted_price[0]:.2f}')
# Out:
# Predicted Sold Price for New Player: 453190.48
